# %% [markdown]
# # Building GloVe

# %% [markdown]
# In this assignment, you're going to implement GloVe, one of the more popular, effective, and efficient approaches to learning word embeddings. You should use the [paper](http://nlp.stanford.edu/pubs/glove.pdf) for reference, and you're welcome to look to other implementations for guidance as long as the code that you submit is your own and it fits the basic structure provided by the starter code below.
#
# Submit your completed notebook through NYU Classes by 9:30 AM on October 13.

# %% [markdown]
# ## Setup

# %% [markdown]
# We're going to run GloVe on the text of the Stanford Sentiment Treebank (SST) training set. Usually these methods are run on extremely large corpora, but we're using this here to make sure that you can train a reasonable model without waiting for hours or days.
#
# First, let's load the data as before. For our purposes, we won't need either the labels or any of the test or dev data.

# %%
sst_home = './trees'

import re

def load_sst_data(path):
    data = []
    with open(path) as f:
        for i, line in enumerate(f): 
            example = {}
            text = re.sub(r'\s*(\(\d)|(\))\s*', '', line)
            example['text'] = text[1:]
            data.append(example)
    return data
     
training_set = load_sst_data(sst_home + '/train.txt')

# %%
training_set
# Out:
# [{'text': "The Rock is destined to be the 21st Century 's new `` Conan '' and that he 's going to make a splash even greater than Arnold Schwarzenegger , Jean-Claud Van Damme or Steven Segal ."},
#  {'text': "The gorgeously elaborate continuation of `` The Lord of the Rings '' trilogy is so huge that a column of words can not adequately describe co-writer\\/director Peter Jackson 's expanded vision of J.R.R. Tolkien 's Middle-earth ."},
#  {'text': 'Singer\\/composer Bryan Adams contributes a slew of songs -- a few potential hits , a few more simply intrusive to the story -- but the whole package certainly captures the intended , er , spirit of the piece .'},
#  {'text': "You 'd think by now America would have had enough of plucky British eccentrics with hearts of gold ."},
#  {'text': 'Yet the act is still charming here .'},
#  {'text': "Whether or not you 're enlightened by any of Derrida 's lectures on `` the other '' and `` the self , '' Derrida is an undeniably fascinating and playful fellow ."},
#  {'text': 'Just the labour involved in creating the layered richness of the imagery in this chiaroscuro of madness and light is astonishing .'},
#  {'text': 'Part of the charm of Satin Rouge is that it avoids the obvious with humour and lightness .'},
#  {'text': "a screenplay more ingeniously constructed than `` Memento ''"},
#  {'text': "`` Extreme Ops '' exceeds expectations ."},
#  {'text': 'Good fun , good action , good acting , good dialogue , good pace , good cinematography .'},
#  {'text': 'You Should Pay Nine Bucks for This : Because you can hear about suffering Afghan refugees on the news and still be unaffected .'},
#  {'text': 'Dramas like this make it human .'},
#  {'text': 'A thunderous ride at first , quiet cadences of pure finesse are few and far between ; their shortage dilutes the potency of otherwise respectable action .'},
#  {'text': 'Still , this flick is fun , and host to some truly excellent sequences .'},
#  {'text': 'Australian actor\\/director John Polson and award-winning English cinematographer Giles Nuttgens make a terrific effort at disguising the obvious with energy and innovation .'},
#  {'text': 'You walk out of The Good Girl with mixed emotions -- disapproval of Justine combined with a tinge of understanding for her actions .'},
#  {'text': "Post 9\\/11 the philosophical message of `` Personal Freedom First '' might not be as palatable as intended ."},
#  {'text': 'Absorbing character study by Andr\xc3\xa9 Turpin .'},
#  {'text': 'If you love reading and\\/or poetry , then by all means check it out .'},
#  {'text': "You 'll probably love it ."},
#  {'text': "`` Frailty '' has been written so well , that even a simple `` Goddammit ! ''"},
#  {'text': 'near the end takes on a whole other meaning .'},
#  {'text': "Grenier is terrific , bringing an unforced , rapid-fire delivery to Toback 's Heidegger - and Nietzsche-referencing dialogue ."},
#  {'text': 'The Sundance Film Festival has become so buzz-obsessed that fans and producers descend upon Utah each January to ferret out The Next Great Thing .'},
#  {'text': "` Tadpole ' was one of the films so declared this year , but it 's really more of The Next Pretty Good Thing ."},
#  {'text': 'The actors are fantastic .'},
#  {'text': 'They are what makes it worth the trip to the theatre .'},
#  {'text': "-LRB- Taymor -RRB- utilizes the idea of making Kahlo 's art a living , breathing part of the movie , often catapulting the artist into her own work ."},
#  {'text': "This is n't a new idea ."},
#  {'text': "It 's been done before but never so vividly or with so much passion ."},
#  {'text': "-LRB- `` Take Care of My Cat '' -RRB- is an honestly nice little film that takes us on an examination of young adult life in urban South Korea through the hearts and minds of the five principals ."},
#  {'text': "It 's not life-affirming -- its vulgar and mean , but I liked it ."},
#  {'text': "What `` Empire '' lacks in depth it makes up for with its heart ."},
#  {'text': 'Light , silly , photographed with colour and depth , and rather a good time .'},
#  {'text': "But tongue-in-cheek preposterousness has always been part of For the most part Wilde 's droll whimsy helps `` Being Earnest '' overcome its weaknesses and Parker 's creative interference ..."},
#  {'text': "Much of the movie 's charm lies in the utter cuteness of Stuart and Margolo ."},
#  {'text': 'Their computer-animated faces are very expressive .'},
#  {'text': "The path Ice Age follows most closely , though , is the one established by Warner Bros. giant Chuck Jones , who died a matter of weeks before the movie 's release ."},
#  {'text': "... spiced with humor -LRB- ' I speak fluent flatula , ' advises Denlopp after a rather , er , bubbly exchange with an alien deckhand -RRB- and witty updatings -LRB- Silver 's parrot has been replaced with Morph , a cute alien creature who mimics everyone and everything around -RRB-"},
#  {'text': "There 's an energy to Y Tu Mam\xc3\xa1 Tambi\xc3\xa9n ."},
#  {'text': 'Much of it comes from the brave , uninhibited performances by its lead actors .'},
#  {'text': "`` 13 Conversations '' holds its goodwill close , but is relatively slow to come to the point ."},
#  {'text': "`` Auto Focus '' works as an unusual biopic and document of male swingers in the Playboy era"},
#  {'text': "If Mr. Zhang 's subject matter is , to some degree at least , quintessentially American , his approach to storytelling might be called Iranian ."},
#  {'text': "... a sour little movie at its core ; an exploration of the emptiness that underlay the relentless gaiety of the 1920 's ... The film 's ending has a `` What was it all for ? ''"},
#  {'text': "feeling to it , but like the 1920 's , the trip there is a great deal of fun ."},
#  {'text': "`` Cremaster 3 '' should come with the warning `` For serious film buffs only ! ''"},
#  {'text': 'Made me unintentionally famous -- as the queasy-stomached critic who staggered from the theater and blacked out in the lobby .'},
#  {'text': "But believe it or not , it 's one of the most beautiful , evocative works I 've seen ."},
#  {'text': "Garc\xc3\xada Bernal and Talanc\xc3\xb3n are an immensely appealing couple , and even though their story is predictable , you 'll want things to work out ."},
#  {'text': '... a spoof comedy that carries its share of laughs -- sometimes a chuckle , sometimes a guffaw and , to my great pleasure , the occasional belly laugh .'},
#  {'text': "-LRB- City -RRB- reminds us how realistically nuanced a Robert De Niro performance can be when he is not more lucratively engaged in the shameless self-caricature of ` Analyze This ' -LRB- 1999 -RRB- and ` Analyze That , ' promised -LRB- or threatened -RRB- for later this year ."},
#  {'text': 'The wanton slipperiness of \\* Corpus and its amiable jerking and reshaping of physical time and space would make it a great piece to watch with kids and use to introduce video as art .'},
#  {'text': "`` Frailty '' starts out like a typical Bible killer story , but it turns out to be significantly different -LRB- and better -RRB- than most films with this theme ."},
#  {'text': 'For those who pride themselves on sophisticated , discerning taste , this might not seem like the proper cup of tea , however it is almost guaranteed that even the stuffiest cinema goers will laugh their \\*\\*\\* off for an hour-and-a-half .'},
#  {'text': 'It cuts to the core of what it actually means to face your fears , to be a girl in a world of boys , to be a boy truly in love with a girl , and to ride the big metaphorical wave that is life -- wherever it takes you .'},
#  {'text': 'A welcome relief from baseball movies that try too hard to be mythic , this one is a sweet and modest and ultimately winning story .'},
#  {'text': "A crisp psychological drama -LRB- and -RRB- a fascinating little thriller that would have been perfect for an old `` Twilight Zone '' episode ."},
#  {'text': 'It has more than a few moments that are insightful enough to be fondly remembered in the endlessly challenging maze of moviegoing .'},
#  {'text': 'Opening with some contrived banter , cliches and some loose ends , the screenplay only comes into its own in the second half .'},
#  {'text': "An uncluttered , resonant gem that relays its universal points without lectures or confrontations . '"},
#  {'text': "-LRB- The Cockettes -RRB- provides a window into a subculture hell-bent on expressing itself in every way imaginable . '"},
#  {'text': 'A smart , steamy mix of road movie , coming-of-age story and political satire .'},
#  {'text': 'The modern-day royals have nothing on these guys when it comes to scandals .'},
#  {'text': "It 's only in fairy tales that princesses that are married for political reason live happily ever after ."},
#  {'text': 'A terrific B movie -- in fact , the best in recent memory .'},
#  {'text': "`` Birthday Girl '' is an actor 's movie first and foremost ."},
#  {'text': 'I walked away from this new version of E.T. just as I hoped I would -- with moist eyes .'},
#  {'text': "For devotees of French cinema , Safe Conduct is so rich with period minutiae it 's like dying and going to celluloid heaven ."},
#  {'text': "What 's really so appealing about the characters is their resemblance to everyday children ."},
#  {'text': "Shamelessly resorting to pee-related sight gags that might even cause Tom Green a grimace ; still , Myer 's energy and the silliness of it all eventually prevail"},
#  {'text': 'An absurdist spider web .'},
#  {'text': "If you 're as happy listening to movies as you are watching them , and the slow parade of human frailty fascinates you , then you 're at the right film ."},
#  {'text': "This version moves beyond the original 's nostalgia for the communal film experiences of yesteryear to a deeper realization of cinema 's inability to stand in for true , lived experience ."},
#  {'text': 'Some movies blend together as they become distant memories .'},
#  {'text': "Mention `` Solaris '' five years from now and I 'm sure those who saw it will have an opinion to share ."},
#  {'text': "Allen 's funniest and most likeable movie in years ."},
#  {'text': "It 's a glorious spectacle like those D.W. Griffith made in the early days of silent film ."},
#  {'text': 'This comic gem is as delightful as it is derivative .'},
#  {'text': 'More timely than its director could ever have dreamed , this quietly lyrical tale probes the ambiguous welcome extended by Iran to the Afghani refugees who streamed across its borders , desperate for work and food .'},
#  {'text': 'The leaping story line , shaped by director Peter Kosminsky into sharp slivers and cutting impressions , shows all the signs of rich detail condensed into a few evocative images and striking character traits .'},
#  {'text': "With three excellent principal singers , a youthful and good-looking diva and tenor and richly handsome locations , it 's enough to make you wish Jacquot had left well enough alone and just filmed the opera without all these distortions of perspective ."},
#  {'text': 'The production has been made with an enormous amount of affection , so we believe these characters love each other .'},
#  {'text': 'Certainly the performances are worthwhile .'},
#  {'text': 'Winds up being both revelatory and narcissistic , achieving some honest insight into relationships that most high-concept films candy-coat with pat storylines , precious circumstances and beautiful stars .'},
#  {'text': 'Watching these eccentrics is both inspiring and pure joy .'},
#  {'text': 'Steven Spielberg brings us another masterpiece'},
#  {'text': "Finally , the French-produced `` Read My Lips '' is a movie that understands characters must come first ."},
#  {'text': 'Ms. Seigner and Mr. Serrault bring fresh , unforced naturalism to their characters .'},
#  {'text': 'Allen shows he can outgag any of those young whippersnappers making moving pictures today .'},
#  {'text': 'A good film with a solid pedigree both in front of and , more specifically , behind the camera .'},
#  {'text': 'By no means a slam-dunk and sure to ultimately disappoint the action fans who will be moved to the edge of their seats by the dynamic first act , it still comes off as a touching , transcendent love story .'},
#  {'text': "I encourage young and old alike to go see this unique and entertaining twist on the classic whale 's tale -- you wo n't be sorry !"},
#  {'text': "A literary detective story is still a detective story and aficionados of the whodunit wo n't be disappointed ."},
#  {'text': "High Crimes steals so freely from other movies and combines enough disparate types of films that it ca n't help but engage an audience ."},
#  {'text': "If you 're a fan of the series you 'll love it and probably want to see it twice ."},
#  {'text': 'I will be .'},
#  {'text': "It celebrates the group 's playful spark of nonconformity , glancing vividly back at what Hibiscus grandly called his ` angels of light . '"},
#  {'text': 'The story ... is inspiring , ironic , and revelatory of just how ridiculous and money-oriented the record industry really is .'},
#  {'text': 'It is also a testament to the integrity and vision of the band .'},
#  {'text': 'Laced with liberal doses of dark humor , gorgeous exterior photography , and a stable-full of solid performances , No Such Thing is a fascinating little tale .'},
#  {'text': "Huppert 's show to steal and she makes a meal of it , channeling Kathy Baker 's creepy turn as the repressed mother on Boston Public just as much as 8 Women 's Augustine ."},
#  {'text': "Nair does n't treat the issues lightly ."},
#  {'text': 'She allows each character to confront their problems openly and honestly .'},
#  {'text': 'One of the best silly horror movies of recent memory , with some real shocks in store for unwary viewers .'},
#  {'text': 'The work of a filmmaker who has secrets buried at the heart of his story and knows how to take time revealing them .'},
#  {'text': 'Strange occurrences build in the mind of the viewer and take on extreme urgency .'},
#  {'text': 'Has a certain ghoulish fascination , and generates a fair amount of B-movie excitement .'},
#  {'text': 'Familiar but utterly delightful .'},
#  {'text': 'A fascinating , dark thriller that keeps you hooked on the delicious pulpiness of its lurid fiction .'},
#  {'text': 'The film aims to be funny , uplifting and moving , sometimes all at once .'},
#  {'text': 'The extent to which it succeeds is impressive .'},
#  {'text': 'The film brilliantly shines on all the characters , as the direction is intelligently accomplished .'},
#  {'text': 'While not for every taste , this often very funny collegiate gross-out comedy goes a long way toward restoring the luster of the National Lampoon film franchise , too long reduced to direct-to-video irrelevancy .'},
#  {'text': 'As broad and cartoonish as the screenplay is , there is an accuracy of observation in the work of the director , Frank Novak , that keeps the film grounded in an undeniable social realism .'},
#  {'text': "In addition to Hoffman 's powerful acting clinic , this is that rare drama that offers a thoughtful and rewarding glimpse into the sort of heartache everyone has felt , or will feel someday ."},
#  {'text': "Jeffrey Tambor 's performance as the intelligent jazz-playing exterminator is Oscar-worthy ."},
#  {'text': "From the opening strains of the Average White Band 's `` Pick up the Pieces '' , you can feel the love ."},
#  {'text': "Stevens ' vibrant creative instincts are the difference between this and countless other flicks about guys and dolls ."},
#  {'text': "that it 'll probably be the best and most mature comedy of the 2002 summer season speaks more of the season than the picture"},
#  {'text': 'Old people will love this movie , and I mean that in the nicest possible way : Last Orders will touch the heart of anyone old enough to have earned a 50-year friendship .'},
#  {'text': "Meyjes ' provocative film might be called an example of the haphazardness of evil ."},
#  {'text': "Tian emphasizes the isolation of these characters by confining color to Liyan 's backyard ."},
#  {'text': 'The movie is pretty funny now and then without in any way demeaning its subjects .'},
#  {'text': "imagine a scenario where Bergman approaches Swedish fatalism using Gary Larson 's Far Side humor"},
#  {'text': 'Too damn weird to pass up , and for the blacklight crowd , way cheaper -LRB- and better -RRB- than Pink Floyd tickets .'},
#  {'text': 'It is most remarkable not because of its epic scope , but because of the startling intimacy it achieves despite that breadth .'},
#  {'text': "It 's not a great monster movie ."},
#  {'text': "But if you 've paid a matinee price and bought a big tub of popcorn , there 's guilty fun to be had here ."},
#  {'text': 'Chomp chomp !'},
#  {'text': 'The Grey Zone gives voice to a story that needs to be heard in the sea of Holocaust movies ... but the film suffers from its own difficulties .'},
#  {'text': "Others , more attuned to the anarchist maxim that ` the urge to destroy is also a creative urge ' , or more willing to see with their own eyes , will find Morrison 's iconoclastic uses of technology to be liberating ."},
#  {'text': 'Miller tells this very compelling tale with little fuss or noise , expertly plucking tension from quiet .'},
#  {'text': 'Time Out is existential drama without any of the pretension associated with the term .'},
#  {'text': "It 's a sweet , laugh-a-minute crowd pleaser that lifts your spirits as well as the corners of your mouth ."},
#  {'text': 'Writer\\/director Alexander Payne -LRB- Election -RRB- and his co-writer Jim Taylor brilliantly employ their quirky and fearless ability to look American angst in the eye and end up laughing .'},
#  {'text': "A movie that at its best does n't just make the most out of its characters ' flaws but insists on the virtue of imperfection ."},
#  {'text': "It 's tough to watch , but it 's a fantastic movie ."},
#  {'text': 'The best animated feature to hit theaters since Beauty and the Beast 11 years ago .'},
#  {'text': "What saves this deeply affecting film from being merely a collection of wrenching cases is Corcuera 's attention to detail ."},
#  {'text': "Pacino is the best he 's been in years and Keener is marvelous ."},
#  {'text': 'A solid , spooky entertainment worthy of the price of a ticket .'},
#  {'text': 'By turns fanciful , grisly and engagingly quixotic .'},
#  {'text': '... very funny , very enjoyable ...'},
#  {'text': "Adaptation is intricately constructed and in a strange way nails all of Orlean 's themes without being a true adaptation of her book ."},
#  {'text': "So purely enjoyable that you might not even notice it 's a fairly straightforward remake of Hollywood comedies such as Father of the Bride ."},
#  {'text': 'Moonlight Mile gives itself the freedom to feel contradictory things .'},
#  {'text': 'It is sentimental but feels free to offend , is analytical and then surrenders to the illogic of its characters , is about grief and yet permits laughter .'},
#  {'text': "The real triumphs in Igby come from Philippe , who makes Oliver far more interesting than the character 's lines would suggest , and Sarandon , who could n't be better as a cruel but weirdly likable WASP matron ."},
#  {'text': 'Robin Williams has thankfully ditched the saccharine sentimentality of Bicentennial Man in favour of an altogether darker side .'},
#  {'text': "If you 're willing to have fun with it , you wo n't feel cheated by the high infidelity of Unfaithful ."},
#  {'text': 'Australia : Land Beyond Time is an enjoyable Big Movie primarily because Australia is a weirdly beautiful place .'},
#  {'text': "Hoffman 's performance is authentic to the core of his being ."},
#  {'text': 'Told just proficiently enough to trounce its overly comfortable trappings .'},
#  {'text': "An enthralling aesthetic experience , one that 's steeped in mystery and a ravishing , baroque beauty ."},
#  {'text': 'The quirky drama touches the heart and the funnybone thanks to the energetic and always surprising performance by Rachel Griffiths .'},
#  {'text': 'A captivating coming-of-age story that may also be the first narrative film to be truly informed by the wireless age .'},
#  {'text': "What could have been a daytime soap opera is actually a compelling look at a young woman 's tragic odyssey ."},
#  {'text': 'Duvall is strong as always .'},
#  {'text': 'A no-holds-barred cinematic treat .'},
#  {'text': "You 'd have to be a most hard-hearted person not to be moved by this drama ."},
#  {'text': "Allen 's underestimated charm delivers more goodies than lumps of coal ."},
#  {'text': 'Measured against practically any like-themed film other than its Oscar-sweeping franchise predecessor The Silence of the Lambs , Red Dragon rates as an exceptional thriller .'},
#  {'text': 'An exhilarating serving of movie fluff .'},
#  {'text': 'Maelstrom is strange and compelling , engrossing and different , a moral tale with a twisted sense of humor .'},
#  {'text': 'It makes you believe the cast and crew thoroughly enjoyed themselves and believed in their small-budget film .'},
#  {'text': 'Dark and disturbing , yet compelling to watch .'},
#  {'text': "Too often , Son of the Bride becomes an exercise in trying to predict when a preordained `` big moment '' will occur and not `` if . ''"},
#  {'text': 'The picture uses humor and a heartfelt conviction to tell a story about discovering your destination in life , but also acknowledging the places , and the people , from whence you came .'},
#  {'text': 'A solid piece of journalistic work that draws a picture of a man for whom political expedience became a deadly foreign policy .'},
#  {'text': 'A terrific insider look at the star-making machinery of tinseltown .'},
#  {'text': "It 's a diverting enough hour-and-a-half for the family audience ."},
#  {'text': 'A party-hearty teen flick that scalds like acid .'},
#  {'text': 'As giddy and whimsical and relevant today as it was 270 years ago .'},
#  {'text': 'The film offers an intriguing what-if premise .'},
#  {'text': 'The Pianist is the film Roman Polanski may have been born to make .'},
#  {'text': 'This version does justice both to Stevenson and to the sci-fi genre .'},
#  {'text': 'Poignant and delicately complex .'},
#  {'text': 'Enough may pander to our basest desires for payback , but unlike many revenge fantasies , it ultimately delivers .'},
#  {'text': "Cho 's latest comic set is n't as sharp or as fresh as I 'm the One That I Want ... but it 's still damn funny stuff ."},
#  {'text': 'In The Pianist , Polanski is saying what he has long wanted to say , confronting the roots of his own preoccupations and obsessions , and he allows nothing to get in the way .'},
#  {'text': "Despite the film 's shortcomings , the stories are quietly moving ."},
#  {'text': 'Those who love Cinema Paradiso will find the new scenes interesting , but few will find the movie improved .'},
#  {'text': 'If you come from a family that eats , meddles , argues , laughs , kibbitzes and fights together , then go see this delightful comedy .'},
#  {'text': 'This bracingly truthful antidote to Hollywood teenage movies that slather Clearasil over the blemishes of youth captures the combustible mixture of a chafing inner loneliness and desperate grandiosity that tend to characterize puberty .'},
#  {'text': "The reason to see `` Sade '' lay with the chemistry and complex relationship between the marquis -LRB- Auteil -RRB- and Emilie -LRB- Le Besco -RRB- ."},
#  {'text': "It 's the filmmakers ' post-camp comprehension of what made old-time B movies good-bad that makes Eight Legged Freaks a perfectly entertaining summer diversion ."},
#  {'text': "The film 's strength is n't in its details , but in the larger picture it paints - of a culture in conflict with itself , with the thin veneer of nationalism that covers our deepest , media-soaked fears ."},
#  {'text': '... best seen as speculative history , as much an exploration of the paranoid impulse as a creative sequel to the Warren Report .'},
#  {'text': 'It has its faults , but it is a kind , unapologetic , sweetheart of a movie , and Mandy Moore leaves a positive impression .'},
#  {'text': 'The Saigon of 1952 is an uneasy mix of sensual delights and simmering violence , and The Quiet American brings us right into the center of that world .'},
#  {'text': "Despite its shortcomings , Girls Ca n't Swim represents an engaging and intimate first feature by a talented director to watch , and it 's a worthy entry in the French coming-of-age genre ."},
#  {'text': "Flawed , but worth seeing for Ambrose 's performance ."},
#  {'text': 'With Dirty Deeds , David Caesar has stepped into the mainstream of filmmaking with an assurance worthy of international acclaim and with every cinematic tool well under his control -- driven by a natural sense for what works on screen .'},
#  {'text': 'The humor and humanity of Monsoon Wedding are in perfect balance .'},
#  {'text': "Lookin ' for sin , American-style ?"},
#  {'text': 'Try Hell House , which documents the cautionary Christian spook-a-rama of the same name .'},
#  {'text': 'A compelling motion picture that illustrates an American tragedy .'},
#  {'text': 'As comedic spotlights go , Notorious C.H.O. hits all the verbal marks it should .'},
#  {'text': "It 's a day at the beach -- with air conditioning and popcorn ."},
#  {'text': "Frida is n't that much different from many a Hollywood romance ."},
#  {'text': "What sets it apart is the vision that Taymor , the avant garde director of Broadway 's The Lion King and the film Titus , brings ."},
#  {'text': 'Stevens has a flair for dialogue comedy , the film operates nicely off the element of surprise , and the large cast is solid .'},
#  {'text': 'Extremely well acted by the four primary actors , this is a seriously intended movie that is not easily forgotten .'},
#  {'text': 'The film exudes the urbane sweetness that Woody Allen seems to have bitterly forsaken .'},
#  {'text': 'K-19 : The Widowmaker is derivative , overlong , and bombastic -- yet surprisingly entertaining .'},
#  {'text': "It 's good , hard-edged stuff , violent and a bit exploitative but also nicely done , morally alert and street-smart ."},
#  {'text': "Cineasts will revel in those visual in-jokes , as in the film 's verbal pokes at everything from the likes of Miramax chief Harvey Weinstein 's bluff personal style to the stylistic rigors of Denmark 's Dogma movement ."},
#  {'text': "It 's a rare window on an artistic collaboration ."},
#  {'text': '... begins with promise , but runs aground after being snared in its own tangled plot .'},
#  {'text': "Perhaps the best sports movie I 've ever seen ."},
#  {'text': "Cho 's timing is priceless ."},
#  {'text': "... creates a visceral sense of its characters ' lives and conflicted emotions that carries it far above ... what could have been a melodramatic , Lifetime Channel-style anthology ."},
#  {'text': 'A sensitive , moving , brilliantly constructed work .'},
#  {'text': 'An edgy thriller that delivers a surprising punch .'},
#  {'text': "A reasonably entertaining sequel to 1994 's surprise family hit that may strain adult credibility ."},
#  {'text': '-LRB- Reno -RRB- delivers a monologue that manages to incorporate both the horror and the absurdity of the situation in a well-balanced fashion .'},
#  {'text': 'there is truth here'},
#  {'text': "a confident , richly acted , emotionally devastating piece of work and 2002 's first great film"},
#  {'text': 'A touching , small-scale story of family responsibility and care in the community .'},
#  {'text': 'Arteta directs one of the best ensemble casts of the year'},
#  {'text': "The casting of von Sydow ... is itself Intacto 's luckiest stroke ."},
#  {'text': "No , it 's not as single-minded as John Carpenter 's original , but it 's sure a lot smarter and more unnerving than the sequels ."},
#  {'text': 'A gem of a romantic crime comedy that turns out to be clever , amusing and unpredictable .'},
#  {'text': "Stands as one of the year 's most intriguing movie experiences , letting its imagery speak for it while it forces you to ponder anew what a movie can be ."},
#  {'text': '... the first 2\\/3 of the film are incredibly captivating and insanely funny , thanks in part to interesting cinematic devices -LRB- cool visual backmasking -RRB- , a solid cast , and some wickedly sick and twisted humor ...'},
#  {'text': 'This movie got me grinning .'},
#  {'text': "There 's a part of us that can not help be entertained by the sight of someone getting away with something ."},
#  {'text': "An old-fashioned drama of substance about a teacher 's slide down the slippery slope of dishonesty after an encounter with the rich and the powerful who have nothing but disdain for virtue ."},
#  {'text': "What 's not to like about a movie with a ` children 's ' song that includes the line ` My stepdad 's not mean , he 's just adjusting ' ?"},
#  {'text': "This English-language version ... does full honor to Miyazaki 's teeming and often unsettling landscape , and to the conflicted complexity of his characters ."},
#  {'text': 'The pleasures that it does afford may be enough to keep many moviegoers occupied amidst some of the more serious-minded concerns of other year-end movies .'},
#  {'text': 'Not everyone will welcome or accept The Trials of Henry Kissinger as faithful portraiture , but few can argue that the debate it joins is a necessary and timely one .'},
#  {'text': 'There are no special effects , and no Hollywood endings .'},
#  {'text': "Like the original , this version is raised a few notches above kiddie fantasy pablum by Allen 's astringent wit ."},
#  {'text': "Despite its Hawaiian setting , the science-fiction trimmings and some moments of rowdy slapstick , the basic plot of `` Lilo '' could have been pulled from a tear-stained vintage Shirley Temple script ."},
#  {'text': 'A brutally honest documentary about a much anticipated family reunion that goes wrong thanks to culture shock and a refusal to empathize with others .'},
#  {'text': 'Filled with honest performances and exceptional detail , Baran is a gentle film with dramatic punch , a haunting ode to humanity .'},
#  {'text': "Sparkles in its deft portrait of Tinseltown 's seasoned veterans of gossip , wealth , paranoia , and celebrityhood ."},
#  {'text': "In its dry and forceful way , it delivers the same message as Jiri Menzel 's Closely Watched Trains and Danis Tanovic 's No Man 's Land ."},
#  {'text': '... a triumph of emotionally and narratively complex filmmaking .'},
#  {'text': "-LRB- Haynes ' -RRB- homage to such films as `` All That Heaven Allows '' and `` Imitation of Life '' transcends them ."},
#  {'text': "Simply put , `` Far From Heaven '' is a masterpiece ."},
#  {'text': 'An intense and effective film about loneliness and the chilly anonymity of the environments where so many of us spend so much of our time .'},
#  {'text': "Although fairly involving as far as it goes , the film does n't end up having much that is fresh to say about growing up Catholic or , really , anything ."},
#  {'text': 'Proves mainly that South Korean filmmakers can make undemanding action movies with all the alacrity of their Hollywood counterparts .'},
#  {'text': 'A very funny romantic comedy about two skittish New York middle-agers who stumble into a relationship and then struggle furiously with their fears and foibles .'},
#  {'text': 'Top-notch action powers this romantic drama .'},
#  {'text': 'Beresford nicely mixes in as much humor as pathos to take us on his sentimental journey of the heart .'},
#  {'text': "It really is a shame that more wo n't get an opportunity to embrace small , sweet ` Evelyn . '"},
#  {'text': 'I stopped thinking about how good it all was , and started doing nothing but reacting to it - feeling a part of its grand locations , thinking urgently as the protagonists struggled , feeling at the mercy of its inventiveness , gasping at its visual delights .'},
#  {'text': 'Probably the best case for Christianity since Chesterton and Lewis .'},
#  {'text': 'A gently funny , sweetly adventurous film that makes you feel genuinely good , that is to say , entirely unconned by false sentiment or sharp , overmanipulative Hollywood practices .'},
#  {'text': 'Would be an unendurable viewing experience for this ultra-provincial New Yorker if 26-year-old Reese Witherspoon were not on hand to inject her pure fantasy character , Melanie Carmichael , with a massive infusion of old-fashioned Hollywood magic .'},
#  {'text': 'Visually fascinating ... an often intense character study about fathers and sons , loyalty and duty .'},
#  {'text': 'A lyrical metaphor for cultural and personal self-discovery and a picaresque view of a little-remembered world .'},
#  {'text': "Sch\xc3\xbctte 's dramatic snapshot of the artist three days before his death offers an interesting bit of speculation as to the issues Brecht faced as his life drew to a close ."},
#  {'text': 'A slick , engrossing melodrama .'},
#  {'text': "S1M0NE 's satire is not subtle , but it is effective ."},
#  {'text': "It 's a quirky , off-beat project ."},
#  {'text': 'While some will object to the idea of a Vietnam picture with such a rah-rah , patriotic tone , Soldiers ultimately achieves its main strategic objective : dramatizing the human cost of the conflict that came to define a generation .'},
#  {'text': "Even if you do n't know the band or the album 's songs by heart , you will enjoy seeing how both evolve , and you will also learn a good deal about the state of the music business in the 21st Century ."},
#  {'text': 'The solid filmmaking and convincing characters makes this a high water mark for this genre .'},
#  {'text': 'Films about loss , grief and recovery are pretty valuable these days .'},
#  {'text': 'Seen in that light , Moonlight Mile should strike a nerve in many .'},
#  {'text': "It 's endlessly inventive , consistently intelligent and sickeningly savage ."},
#  {'text': 'It is definitely worth seeing .'},
#  {'text': 'An impeccable study in perversity .'},
#  {'text': "Far From Heaven is a dazzling conceptual feat , but more than that , it 's a work of enthralling drama ."},
#  {'text': 'A movie that both thrills the eye and , in its over-the-top way , touches the heart .'},
#  {'text': "Stuffed to the brim with ideas , American instigator Michael Moore 's film is a rambling examination of American gun culture that uses his usual modus operandi of crucifixion through juxtaposition ."},
#  {'text': 'Affectionately reminds us that , in any language , the huge stuff in life can usually be traced back to the little things .'},
#  {'text': 'A drama of great power , yet some members of the audience will leave the theater believing they have seen a comedy .'},
#  {'text': 'The large-frame IMAX camera lends itself beautifully to filming the teeming life on the reefs , making this gorgeous film a must for everyone from junior scientists to grown-up fish lovers .'},
#  {'text': "The result is more depressing than liberating , but it 's never boring ."},
#  {'text': 'A story about intelligent high school students that deals with first love sweetly but also seriously .'},
#  {'text': 'It is also beautifully acted .'},
#  {'text': "It is n't that the picture is unfamiliar , but that it manages to find new avenues of discourse on old problems ."},
#  {'text': 'Same song , second verse , coulda been better , but it coulda been worse .'},
#  {'text': "It 's a technically superb film , shining with all the usual Spielberg flair , expertly utilizing the talents of his top-notch creative team ."},
#  {'text': 'Wilco fans will have a great time , and the movie should win the band a few new converts , too .'},
#  {'text': "Tsai has a well-deserved reputation as one of the cinema world 's great visual stylists , and in this film , every shot enhances the excellent performances ."},
#  {'text': 'The date movie that Franz Kafka would have made .'},
#  {'text': "The fact is that the screen is most alive when it seems most likely that Broomfield 's interviewees , or even himself , will not be for much longer ."},
#  {'text': 'Leguizamo and Jones are both excellent and the rest of the cast is uniformly superb .'},
#  {'text': 'I liked this film a lot ...'},
#  {'text': "... there is enough originality in ` Life ' to distance it from the pack of paint-by-number romantic comedies that so often end up on cinema screens ."},
#  {'text': 'A solid and refined piece of moviemaking imbued with passion and attitude .'},
#  {'text': 'Nettelbeck has crafted an engaging fantasy of flavours and emotions , one part romance novel , one part recipe book .'},
#  {'text': 'With or without the sex , a wonderful tale of love and destiny , told well by a master storyteller'},
#  {'text': "On the surface a silly comedy , Scotland , PA would be forgettable if it were n't such a clever adaptation of the bard 's tragic play ."},
#  {'text': 'A weird , arresting little ride .'},
#  {'text': 'A fine film , but it would be a lot better if it stuck to Betty Fisher and left out the other stories .'},
#  {'text': 'A first-class road movie that proves you can run away from home , but your ego and all your problems go with you .'},
#  {'text': "You might want to take a reality check before you pay the full ticket price to see `` Simone , '' and consider a DVD rental instead ."},
#  {'text': 'Well cast and well directed - a powerful drama with enough sardonic wit to keep it from being maudlin .'},
#  {'text': 'A backstage must-see for true fans of comedy .'},
#  {'text': "There 's back-stabbing , inter-racial desire and , most importantly , singing and dancing ."},
#  {'text': "The film sounds like the stuff of lurid melodrama , but what makes it interesting as a character study is the fact that the story is told from Paul 's perspective ."},
#  {'text': 'Jones ... makes a great impression as the writer-director of this little $ 1.8 million charmer , which may not be cutting-edge indie filmmaking but has a huge heart .'},
#  {'text': 'In the disturbingly involving family dysfunctional drama How I Killed My Father , French director Anne Fontaine delivers an inspired portrait of male-ridden angst and the emotional blockage that accompanies this human condition'},
#  {'text': "Below may not mark Mr. Twohy 's emergence into the mainstream , but his promise remains undiminished ."},
#  {'text': "There 's no reason to miss Interview with the Assassin"},
#  {'text': "Happily stays close to the ground in a spare and simple manner and does n't pummel us with phony imagery or music ."},
#  {'text': 'Its sheer dynamism is infectious .'},
#  {'text': 'For his first attempt at film noir , Spielberg presents a fascinating but flawed look at the near future .'},
#  {'text': 'it somehow managed to make its way past my crappola radar and find a small place in my heart'},
#  {'text': "Perhaps it 's cliche to call the film ` refreshing , ' but it is ."},
#  {'text': "` Drumline ' shows a level of young , Black manhood that is funny , touching , smart and complicated ."},
#  {'text': 'It does give a taste of the Burning Man ethos , an appealing blend of counter-cultural idealism and hedonistic creativity .'},
#  {'text': 'The limited sets and small confined and dark spaces also are homages to a classic low-budget film noir movie .'},
#  {'text': 'The movie is well done , but slow .'},
#  {'text': '-LRB- A -RRB- wonderfully loopy tale of love , longing , and voting .'},
#  {'text': 'The fascination comes in the power of the Huston performance , which seems so larger than life and yet so fragile , and in the way the Ivan character accepts the news of his illness so quickly but still finds himself unable to react .'},
#  {'text': 'The last scenes of the film are anguished , bitter and truthful .'},
#  {'text': 'Mr. Koshashvili is a director to watch .'},
#  {'text': 'Predictable storyline and by-the-book scripting is all but washed away by sumptuous ocean visuals and the cinematic stylings of director John Stockwell .'},
#  {'text': 'Antwone Fisher certainly does the trick of making us care about its protagonist and celebrate his victories but , with few exceptions , it rarely stoops to cheap manipulation or corny conventions to do it .'},
#  {'text': 'One feels the dimming of a certain ambition , but in its place a sweetness , clarity and emotional openness that recalls the classics of early Italian neorealism .'},
#  {'text': 'It challenges , this nervy oddity , like modern art should .'},
#  {'text': "Whenever you think you 've figured out Late Marriage , it throws you for a loop ."},
#  {'text': "The Pianist is Polanski 's best film ."},
#  {'text': 'It is a testament of quiet endurance , of common concern , of reconciled survival .'},
#  {'text': "This Orange has some juice , but it 's far from fresh-squeezed ."},
#  {'text': 'A sensitive , modest comic tragedy that works as both character study and symbolic examination of the huge economic changes sweeping modern China .'},
#  {'text': 'High Crimes knows the mistakes that bad movies make and is determined not to make them , and maybe that is nobility of a sort .'},
#  {'text': "Cusack 's just brilliant in this ."},
#  {'text': 'Knows how to make our imagination wonder .'},
#  {'text': "Jae-eun Jeong 's Take Care of My Cat brings a beguiling freshness to a coming-of-age story with such a buoyant , expressive flow of images that it emerges as another key contribution to the flowering of the South Korean cinema ."},
#  {'text': 'The overall fabric is hypnotic , and Mr. Mattei fosters moments of spontaneous intimacy .'},
#  {'text': 'Evokes a palpable sense of disconnection , made all the more poignant by the incessant use of cell phones .'},
#  {'text': 'Malcolm McDowell is cool .'},
#  {'text': 'Paul Bettany is cool .'},
#  {'text': 'Paul Bettany playing Malcolm McDowell ?'},
#  {'text': 'Cool .'},
#  {'text': 'A touching , sophisticated film that almost seems like a documentary in the way it captures an Italian immigrant family on the brink of major changes .'},
#  {'text': '... a trashy little bit of fluff stuffed with enjoyable performances and a bewildering sense of self-importance'},
#  {'text': "An inventive , absorbing movie that 's as hard to classify as it is hard to resist ."},
#  {'text': 'It made me want to get made-up and go see this movie with my sisters .'},
#  {'text': "I thought the relationships were wonderful , the comedy was funny , and the love ` real ' ."},
#  {'text': "-LRB- Caine -RRB- proves once again he has n't lost his touch , bringing off a superb performance in an admittedly middling film ."},
#  {'text': "Bogdanovich puts history in perspective and , via Kirsten Dunst 's remarkable performance , he showcases Davies as a young woman of great charm , generosity and diplomacy ."},
#  {'text': 'This breezy caper movie becomes a soulful , incisive meditation on the way we were , and the way we are .'},
#  {'text': 'A captivating new film .'},
#  {'text': "Those who are n't put off by the film 's austerity will find it more than capable of rewarding them ."},
#  {'text': "It 's a clear-eyed portrait of an intensely lived time , filled with nervous energy , moral ambiguity and great uncertainties ."},
#  {'text': 'Reveals how important our special talents can be when put in service of of others .'},
#  {'text': 'It also shows how deeply felt emotions can draw people together across the walls that might otherwise separate them .'},
#  {'text': 'With the same sort of good-natured fun found in films like Tremors , Eight Legged Freaks is prime escapist fare .'},
#  {'text': 'A sharp , amusing study of the cult of celebrity .'},
#  {'text': 'The sentimental cliches mar an otherwise excellent film .'},
#  {'text': 'A powerful performance from Mel Gibson and a brutal 90-minute battle sequence that does everything but issue you a dog-tag and an M-16 .'},
#  {'text': "A graceful , moving tribute to the courage of New York 's finest and a nicely understated expression of the grief shared by the nation at their sacrifice ."},
#  {'text': 'A coming-of-age tale from New Zealand whose boozy , languid air is balanced by a rich visual clarity and deeply felt performances across the board .'},
#  {'text': 'Made to be Jaglomized is the Cannes Film Festival , the annual Riviera spree of flesh , buzz , blab and money .'},
#  {'text': 'The charming result is Festival in Cannes .'},
#  {'text': "If you 're looking for something new and hoping for something entertaining , you 're in luck ."},
#  {'text': "A hugely rewarding experience that 's every bit as enlightening , insightful and entertaining as Grant 's two best films -- Four Weddings and a Funeral and Bridget Jones 's Diary ."},
#  {'text': "A rip-roaring comedy action fest that 'll put hairs on your chest ."},
#  {'text': "If there 's no art here , it 's still a good yarn -- which is nothing to sneeze at these days ."},
#  {'text': 'Simultaneously heart-breaking and very funny , The Last Kiss is really all about performances .'},
#  {'text': 'There is a subversive element to this Disney cartoon , providing unexpected fizzability .'},
#  {'text': 'An unforgettable look at morality , family , and social expectation through the prism of that omnibus tradition called marriage .'},
#  {'text': 'An enjoyable , if occasionally flawed , experiment .'},
#  {'text': "Miyazaki is one of world cinema 's most wondrously gifted artists and storytellers ."},
#  {'text': 'If Ayurveda can help us return to a sane regimen of eating , sleeping and stress-reducing contemplation , it is clearly a good thing .'},
#  {'text': "Meeting , even exceeding expectations , it 's the best sequel since The Empire Strikes Back ... a majestic achievement , an epic of astonishing grandeur and surprising emotional depth ."},
#  {'text': 'Leigh is one of the rare directors who feels acting is the heart and soul of cinema .'},
#  {'text': 'He allows his cast members to make creative contributions to the story and dialogue .'},
#  {'text': 'This method almost never fails him , and it works superbly here .'},
#  {'text': 'Poetry in motion captured on film .'},
#  {'text': "While it can be a bit repetitive , overall it 's an entertaining and informative documentary ."},
#  {'text': 'Directing with a sure and measured hand , -LRB- Haneke -RRB- steers clear of the sensational and offers instead an unflinching and objective look at a decidedly perverse pathology .'},
#  {'text': 'The entire movie establishes a wonderfully creepy mood .'},
#  {'text': 'I found The Ring moderately absorbing , largely for its elegantly colorful look and sound .'},
#  {'text': 'The filmmakers want nothing else than to show us a good time , and in their cheap , B movie way , they succeed .'},
#  {'text': 'Amari has dressed up this little parable in a fairly irresistible package full of privileged moments and memorable performances .'},
#  {'text': 'Rabbit-Proof Fence will probably make you angry .'},
#  {'text': "But it will just as likely make you weep , and it will do so in a way that does n't make you feel like a sucker ."},
#  {'text': "Both heartbreaking and heartwarming ... just a simple fable done in an artless sytle , but it 's tremendously moving ."},
#  {'text': 'This masterfully calibrated psychological thriller thrives on its taut performances and creepy atmosphere even if the screenplay falls somewhat short .'},
#  {'text': "The film 's sense of imagery gives it a terrible strength , but it 's propelled by the acting ."},
#  {'text': "The Pianist -LRB- is -RRB- a supremely hopeful cautionary tale of war 's madness remembered that we , today , can prevent its tragic waste of life ."},
#  {'text': "Here is a divine monument to a single man 's struggle to regain his life , his dignity and his music ."},
#  {'text': 'Strange it is , but delightfully so .'},
#  {'text': 'Elegant , mannered and teasing .'},
#  {'text': "An average coming-of-age tale elevated by the wholesome twist of a pesky mother interfering during her son 's discovery of his homosexuality ."},
#  {'text': 'The ingenuity that Parker displays in freshening the play is almost in a class with that of Wilde himself .'},
#  {'text': 'Decasia is what has happened already to so many silent movies , newsreels and the like .'},
#  {'text': 'The unexpected thing is that its dying , in this shower of black-and-white psychedelia , is quite beautiful .'},
# ...
#  {'text': 'Uneven , self-conscious but often hilarious spoof .'},
#  {'text': 'Even bigger and more ambitious than the first installment , Spy Kids 2 looks as if it were made by a highly gifted 12-year-old instead of a grown man .'},
#  {'text': "Thanks to The Ch\xc3\xa2teau 's balance of whimsicality , narrative discipline and serious improvisation , almost every relationship and personality in the film yields surprises ."},
#  {'text': 'Alan and his fellow survivors are idiosyncratic enough to lift the movie above its playwriting 101 premise .'},
#  {'text': 'Fresh and raw like a blown-out vein , Narc takes a walking-dead , cop-flick subgenre and beats new life into it .'},
#  {'text': 'The premise of Jason X is silly but strangely believable .'},
#  {'text': "It 's a wise and powerful tale of race and culture forcefully told , with superb performances throughout ."},
#  {'text': 'An awfully good , achingly human picture .'},
#  {'text': "The cast comes through even when the movie does n't ."},
#  {'text': "You 'll laugh at either the obviousness of it all or its stupidity or maybe even its inventiveness , but the point is , you 'll laugh ."},
#  {'text': 'Definitely worth 95 minutes of your time .'},
#  {'text': 'The film jolts the laughs from the audience -- as if by cattle prod .'},
#  {'text': 'A sexy , surprising romance ... Idemoto and Kim make a gorgeous pair ... their scenes brim with sexual possibility and emotional danger .'},
#  {'text': "Toes the fine line between cheese and earnestness remarkably well ; everything is delivered with such conviction that it 's hard not to be carried away ."},
#  {'text': "Whereas Oliver Stone 's conspiracy thriller JFK was long , intricate , star-studded and visually flashy , Interview with the Assassin draws its considerable power from simplicity ."},
#  {'text': 'Funny , sexy , devastating and incurably romantic .'},
#  {'text': "Triple X is a double agent , and he 's one bad dude ."},
#  {'text': "When you 've got the wildly popular Vin Diesel in the equation , it adds up to big box office bucks all but guaranteed ."},
#  {'text': 'Very well-written and very well-acted .'},
#  {'text': 'A powerful and telling story that examines forbidden love , racial tension , and other issues that are as valid today as they were in the 1950s .'},
#  {'text': "You emerge dazed , confused as to whether you 've seen pornography or documentary ."},
#  {'text': "It ai n't art , by a long shot , but unlike last year 's lame Musketeer , this Dumas adaptation entertains ."},
#  {'text': 'likeable thanks to its cast , its cuisine and its quirky tunes .'},
#  {'text': 'Chilling in its objective portrait of dreary , lost twenty-first century America .'},
#  {'text': 'Highly recommended as an engrossing story about a horrifying historical event and the elements which contributed to it .'},
#  {'text': "... there 's enough cool fun here to warm the hearts of animation enthusiasts of all ages ."},
#  {'text': "It manages to squeeze by on Angelina Jolie 's surprising flair for self-deprecating comedy ."},
#  {'text': 'Secretary manages a neat trick , bundling the flowers of perversity , comedy and romance into a strangely tempting bouquet of a movie .'},
#  {'text': "Judith and Zaza 's extended bedroom sequence ... is so intimate and sensual and funny and psychologically self-revealing that it makes most of what passes for sex in the movies look like cheap hysterics ."},
#  {'text': 'Photographed with melancholy richness and eloquently performed yet also decidedly uncinematic .'},
#  {'text': 'A knowing look at female friendship , spiked with raw urban humor .'},
#  {'text': 'As I settled into my World War II memories , I found myself strangely moved by even the corniest and most hackneyed contrivances .'},
#  {'text': 'The overall effect is awe and affection -- and a strange urge to get on a board and , uh , shred , dude .'},
#  {'text': "It 's that rare family movie -- genuine and sweet without relying on animation or dumb humor ."},
#  {'text': "The Trinity Assembly approaches the endeavor with a shocking lack of irony , and George Ratliff 's documentary , Hell House , reflects their earnestness -- which makes for a terrifying film ."},
#  {'text': "Confessions may not be a straightforward bio , nor does it offer much in the way of Barris ' motivations , but the film is an oddly fascinating depiction of an architect of pop culture ."},
#  {'text': 'A special kind of movie , this melancholic film noir reminded me a lot of Memento ...'},
#  {'text': "Simple , poignant and leavened with humor , it 's a film that affirms the nourishing aspects of love and companionship ."},
#  {'text': 'Together , Miller , Kuras and the actresses make Personal Velocity into an intricate , intimate and intelligent journey .'},
#  {'text': 'The wonder of Mostly Martha is the performance of Gedeck , who makes Martha enormously endearing .'},
#  {'text': 'With Notorious C.H.O. Cho proves she has the stuff to stand tall with Pryor , Carlin and Murphy .'},
#  {'text': 'Less front-loaded and more shapely than the two-hour version released here in 1990 .'},
#  {'text': 'Watching War Photographer , you come to believe that Nachtwey hates the wars he shows and empathizes with the victims he reveals .'},
#  {'text': '-LRB- A -RRB- real pleasure in its laid-back way .'},
#  {'text': "Some may choose to interpret the film 's end as hopeful or optimistic but I think Payne is after something darker ."},
#  {'text': 'Though it runs 163 minutes , Safe Conduct is anything but languorous .'},
#  {'text': "It 's packed to bursting with incident , and with scores of characters , some fictional , some from history ."},
#  {'text': 'A much better documentary -- more revealing , more emotional and more surprising -- than its pedestrian English title would have you believe .'},
#  {'text': "Notwithstanding my problem with the movie 's final half hour , I 'm going to recommend SECRETARY , based on the wonderful acting clinic put on by Spader and Gyllenhaal , and also the unique way Shainberg goes about telling what at heart is a sweet little girl -"},
#  {'text': 'A well-crafted film that is all the more remarkable because it achieves its emotional power and moments of revelation with restraint and a delicate ambiguity .'},
#  {'text': "The film has the uncanny ability to right itself precisely when you think it 's in danger of going wrong ."},
#  {'text': "My Big Fat Greek Wedding is that rare animal known as ' a perfect family film , ' because it 's about family ."},
#  {'text': "would make an excellent companion piece to the similarly themed ` The French Lieutenant 's Woman . '"},
#  {'text': '... with the gifted Pearce on hand to keep things on semi-stable ground dramatically , this retooled Machine is ultimately effective enough at achieving the modest , crowd-pleasing goals it sets for itself .'},
#  {'text': "A movie that 's just plain awful but still manages to entertain on a guilty-pleasure , so-bad-it 's - funny level ."},
#  {'text': "A disoriented but occasionally disarming saga packed with moments out of an Alice in Wonderland adventure , a stalker thriller , and a condensed season of TV 's Big Brother ."},
#  {'text': 'Functions as both a revealing look at the collaborative process and a timely , tongue-in-cheek profile of the corporate circus that is the recording industry in the current climate of mergers and downsizing .'},
#  {'text': 'With a confrontational stance , Todd Solondz takes aim on political correctness and suburban families .'},
#  {'text': "A mess , but it 's a sincere mess ."},
#  {'text': 'This odd , distant Portuguese import more or less borrows from Bad Lieutenant and Les Vampires , and comes up with a kind of art-house gay porn film .'},
#  {'text': 'For a debut film , Skin of Man , Heart of Beast feels unusually assured .'},
#  {'text': "A photographic marvel of sorts , and it 's certainly an invaluable record of that special fishy community ."},
#  {'text': "It 's soulful and unslick , and that 's apparently just what -LRB- Aniston -RRB- has always needed to grow into a movie career ."},
#  {'text': "Although Olivier Assayas ' elegantly appointed period drama seems , at times , padded with incident in the way of a too-conscientious adaptation ... its three-hour running time plays closer to two ."},
#  {'text': 'A jaw-droppingly beautiful work that upends nearly every clich\xc3\xa9 of Japanese animation while delivering a more than satisfactory amount of carnage .'},
#  {'text': "Terry is a sort of geriatric Dirty Harry , which will please Eastwood 's loyal fans -- and suits the story , wherein our hero must ride roughshod over incompetent cops to get his man ."},
#  {'text': "Parts seem like they were lifted from Terry Gilliam 's subconscious , pressed through Kafka 's meat grinder and into Bu\xc3\xb1uel 's casings"},
#  {'text': "` Like a child with an important message to tell ... -LRB- Skins ' -RRB- faults are easy to forgive because the intentions are lofty . '"},
#  {'text': 'A delightful entree in the tradition of food movies .'},
#  {'text': "An escapist confection that 's pure entertainment ."},
#  {'text': "The Ring is worth a look , if you do n't demand much more than a few cheap thrills from your Halloween entertainment ."},
#  {'text': "The movie ultimately relies a bit too heavily on grandstanding , emotional , Rocky-like moments ... but it 's such a warm and charming package that you 'll feel too happy to argue much ."},
#  {'text': "Throwing it all away for the fleeting joys of love 's brief moment ."},
#  {'text': 'Armed with a game supporting cast , from the pitch-perfect Forster to the always hilarious Meara and Levy , Like Mike shoots and scores , doing its namesake proud .'},
#  {'text': 'A decent-enough nail-biter that stands a good chance of being the big hit Franklin needs to stay afloat in Hollywood .'},
#  {'text': 'Begins like a docu-drama but builds its multi-character story with a flourish .'},
#  {'text': 'One of the most genuinely sweet films to come along in quite some time .'},
#  {'text': "After an uncertain start , Murder hits and generally sustains a higher plateau with Bullock 's memorable first interrogation of Gosling ."},
#  {'text': 'The story ultimately takes hold and grips hard .'},
#  {'text': 'A bit of a downer and a little over-dramatic at times , but this is a beautiful film for people who like their romances to have that French realism .'},
#  {'text': 'An emotionally strong and politically potent piece of cinema .'},
#  {'text': 'Enticing and often funny documentary .'},
#  {'text': "Going to this movie is a little like chewing whale blubber - it 's an acquired taste that takes time to enjoy , but it 's worth it , even if it does take 3 hours to get through ."},
#  {'text': "A portrait of hell so shattering it 's impossible to shake ."},
#  {'text': "Almodovar is an imaginative teacher of emotional intelligence in this engaging film about two men who discover what William James once called ` the gift of tears . '"},
#  {'text': "Better than the tepid Star Trek : Insurrection ; falls short of First Contact because the villain could n't pick the lint off Borg Queen Alice Krige 's cape ; and finishes half a parsec -LRB- a nose -RRB- ahead of Generations ."},
#  {'text': 'At times a bit melodramatic and even a little dated -LRB- depending upon where you live -RRB- , Ignorant Fairies is still quite good-natured and not a bad way to spend an hour or two .'},
#  {'text': 'Tense , terrific , sweaty-palmed fun .'},
#  {'text': "Majidi 's direction has never been smoother or more confident ."},
#  {'text': 'What a bewilderingly brilliant and entertaining movie this is .'},
#  {'text': 'Hard , endearing , caring , warm .'},
#  {'text': 'Bring tissues .'},
#  {'text': "A thriller with an edge -- which is to say that it does n't follow the stale , standard , connect-the-dots storyline which has become commonplace in movies that explore the seamy underbelly of the criminal world ."},
#  {'text': "`` Me Without You '' is a probing examination of a female friendship set against a few dynamic decades ."},
#  {'text': 'Inherently caustic and oddly whimsical , the film chimes in on the grieving process and strangely draws the audience into the unexplainable pain and eccentricities that are attached to the concept of loss .'},
#  {'text': "Though Frodo 's quest remains unfulfilled , a hardy group of determined New Zealanders has proved its creative mettle ."},
#  {'text': "It 's a square , sentimental drama that satisfies , as comfort food often can ."},
#  {'text': 'Pure cinematic intoxication , a wildly inventive mixture of comedy and melodrama , tastelessness and swooning elegance .'},
#  {'text': "Ramsay is clearly extraordinarily talented , and based on three short films and two features , here 's betting her third feature will be something to behold ."},
#  {'text': 'I was impressed by how many tit-for-tat retaliatory responses the filmmakers allow before pulling the plug on the conspirators and averting an American-Russian Armageddon .'},
#  {'text': 'A classy , sprightly spin on film .'},
#  {'text': 'fast , frantic and fun , but also soon forgotten'},
#  {'text': 'A spiffy animated feature about an unruly adolescent boy who is yearning for adventure and a chance to prove his worth .'},
#  {'text': 'Devos and Cassel have tremendous chemistry -- their sexual and romantic tension , while never really vocalized , is palpable .'},
#  {'text': 'Fulfills the minimum requirement of Disney animation .'},
#  {'text': 'A moving , if uneven , success .'},
#  {'text': "With one exception , every blighter in this particular South London housing project digs into dysfunction like it 's a big , comforting jar of Marmite , to be slathered on crackers and served as a feast of bleakness ."},
#  {'text': 'Wickedly funny , visually engrossing , never boring , this movie challenges us to think about the ways we consume pop culture .'},
#  {'text': "There 's plenty to impress about E.T."},
#  {'text': "A chronicle not only of one man 's quest to be president , but of how that man single-handedly turned a plane full of hard-bitten , cynical journalists into what was essentially , by campaign 's end , an extended publicity department ."},
#  {'text': "Until it goes off the rails in its final 10 or 15 minutes , Wendigo , Larry Fessenden 's spooky new thriller , is a refreshingly smart and newfangled variation on several themes derived from far less sophisticated and knowing horror films ."},
#  {'text': "-LRB- Woo 's -RRB- most resonant film since The Killer ."},
#  {'text': "Collateral Damage is trash , but it earns extra points by acting as if it were n't ."},
#  {'text': 'A whole lot of fun and funny in the middle , though somewhat less hard-hitting at the start and finish .'},
#  {'text': "Maybe it is formula filmmaking , but there 's nothing wrong with that if the film is well-crafted and this one is ."},
#  {'text': "-LRB- Fincher 's -RRB- camera sense and assured pacing make it an above-average thriller ."},
#  {'text': "The film is insightful about Kissinger 's background and history ."},
#  {'text': 'An engrossing portrait of a man whose engaging manner and flamboyant style made him a truly larger-than-life character .'},
#  {'text': "A lot of the credit for the film 's winning tone must go to Grant , who has n't lost a bit of the dry humor that first made audiences on both sides of the Atlantic love him ."},
#  {'text': 'Exploits -LRB- headbanger -RRB- stereotypes in good fun , while adding a bit of heart and unsettling subject matter .'},
#  {'text': "A journey that is as difficult for the audience to take as it is for the protagonist -- yet it 's potentially just as rewarding ."},
#  {'text': "Ratliff 's two previous titles , Plutonium Circus and Purgatory County show his penchant for wry , contentious configurations , and this film is part of that delicate canon ."},
#  {'text': 'From its invitingly upbeat overture to its pathos-filled but ultimately life-affirming finale , Martin is a masterfully conducted work .'},
#  ...]

# %% [markdown]
# Next let's count cooccurrences on the training set. We'll use a nine-word window. Along the way, we'll also collect a list of all of the index pairs $(i,j)$ that have a count greater than zero.
#
# There are faster ways to do this, but this works for a small corpus like ours. To speed up GloVe training below, though, we'll only consider the 250 most frequent words in the corpus.

# %%
import collections
import numpy as np

def tokenize(string):
    return string.split()

word_counter = collections.Counter()
for example in training_set:
    word_counter.update(tokenize(example['text']))
vocabulary = [pair[0] for pair in word_counter.most_common()[0:250]]
index_to_word_map = dict(enumerate(vocabulary))
word_to_index_map = dict([(index_to_word_map[index], index) for index in index_to_word_map])

def extract_cooccurrences(dataset, word_map, amount_of_context=4):
    num_words = len(vocabulary)
    cooccurrences = np.zeros((num_words, num_words))
    nonzero_pairs = set()
    for example in dataset:
        words = tokenize(example['text'])
        for target_index in range(len(words)):
            target_word = words[target_index]
            if target_word not in word_to_index_map:
                continue
            target_word_index = word_to_index_map[target_word]
            min_context_index = max(0, target_index - amount_of_context)
            max_word = min(len(words), target_index + amount_of_context)
            for context_index in range(min_context_index, target_index) + range(target_index + 1, max_word):
                context_word = words[context_index]
                if context_word not in word_to_index_map:
                    continue
                context_word_index = word_to_index_map[context_word]
                cooccurrences[target_word_index][context_word_index] += 1.0
                nonzero_pairs.add((target_word_index, context_word_index))
    return cooccurrences, list(nonzero_pairs)
                
cooccurrences, nonzero_pairs = extract_cooccurrences(training_set, vocabulary)

# vocabulary = most common 250 words, cooccurrences = matrix[word1,word2]=X12

# %% [markdown]
# ## Part 1: Implementation (60%)

# %% [markdown]
# ### Setting up evalation

# %% [markdown]
# To be frank, a GloVe model trained on such a small dataset and vocabulary won't be spectacular, so we won't bother with a full-fledged similarity or analogy evaluation. Instead, we'll use the simple scoring function below, which grades the model on how well it captures ten easy/simple similarity comparisons. The function returns a score between 0 and 10. Random embeddings can be expected to get a score of 5.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def similarity(word_one, word_two):
    vec_one = model.get_embedding(word_to_index_map[word_one]).reshape(1, -1)
    vec_two = model.get_embedding(word_to_index_map[word_two]).reshape(1, -1)
    return float(cosine_similarity(vec_one, vec_two))

def score(model):
    score = 0
    score += similarity('a', 'an') > similarity('a', 'documentary')
    score += similarity('in', 'of') > similarity('in', 'picture')
    score += similarity('action', 'thriller') >  similarity('action', 'end')
    score += similarity('films', 'movies') > similarity('films', 'almost')
    score += similarity('film', 'movie') > similarity('film', 'movies')
    score += similarity('script', 'plot') > similarity('script', 'big')
    score += similarity('watch', 'see') > similarity('watch', 'down')
    score += similarity('``', "''") > similarity('``', 'quite')
    score += similarity('funny', 'entertaining') > similarity('funny', 'seems')
    score += similarity('good', 'great') > similarity('good', 'minutes')
    return score

# %% [markdown]
# Once you've built and trained the model, you can evaluate it as follows. You may not have to, though, since evaluation is built into the model code below.

# %%
score(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-006c66a3fe05> in <module>()
# ----> 1 score(model)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### Defining the model (30%)

# %% [markdown]
# There's some starter code below for training a TensorFlow model. **Fill it out to create an implementation of GloVe, then train it on the SST training set.**
#
# Try not to modify any of the starter code. Leaving it as is will make sure that you'll be able to use my pre-chosen hyperparameter values, which should save you lots of time, since this model is slow to train and hyperparameter tuning is therefore fairly tedious.
#
# Some tips:
#
# - Make sure to fill in all of the TODO lines below.
# - You should use minibatch SGD (the starter code is set up for it), and you should run computation for an entire minibatch at a time using a single `sess.run()` call. This means that many of your variables will have an extra batch dimension in addition to the dimensions that you'd expect from reading the paper.
# - Every time you define any new TF computation, add a comment indicating what shape (/dimensions) you expect the result to be. Use `tf.Print()` and `tf.shape()` to make sure that you're getting what you expect.
# - You'll likely need to use `tf.reshape()` and `tf.batch_matmul()` at least once each.
# - If you're new to TF, try to find a partner or group to work with. The solution is fairly simple, but finding it may not be.

# %%
import tensorflow as tf
import random

class glove:
    def __init__(self, num_words):
        # Define the hyperparameters
        self.dim = 10                # The size of the learned embeddings
        self.alpha = 0.75            # One of the hyperparameters defining the scaling function F
        self.xmax = 50               # One of the hyperparameters defining the scaling function F 
        self.learning_rate = 1.0     # SGD LR - Much higher than you'll see for typical NNs, but it works here
        self.batch_size = 1024       # Somewhat arbitrary - can be tuned, but often tuned for speed, not accuracy
        self.training_epochs = 2000  # This model should train faster per epoch than the logistic regression models,
                                     # so we can afford to run for more epochs. You should feel free to stop the model
                                     # during training if it seems to stop improving.
        self.display_epoch_freq = 25 # How often to test and print out statistics
        self.num_words = num_words   # The number of vectors to learn
        self.embeddings = None       # To be set later
    
        # Define the inputs to the model
        pass # TODO: Replace
        self.train_inputs = tf.placeholder(tf.int32, shape=[self.batch_size])
        self.train_labels = tf.placeholder(tf.int32, shape=[self.batch_size])
        self.coor = tf.placeholder(tf.float32, shape=[self.batch_size])
        
        # Define the trainable parameters of the model
        pass # TODO: Replace
        self.tempEmbeddings = tf.Variable(tf.random_uniform([len(vocabulary), self.dim], -1.0, 1.0))
        self.tempBias = tf.Variable(tf.random_uniform([len(vocabulary)], -1.0, 1.0))
        
        # Define the forward computation of the model
        # The final result that you compute should be a 1024-dimensional vector of example-by-example 
        # cost function values called `self.example_cost`.
        pass # TODO: Replace
#         target_embed = tf.nn.embedding_lookup(self.tempEmbeddings, self.train_inputs)
#         target_bias = tf.nn.embedding_lookup(self.tempBias,self.train_inputs)
#         label_embed = tf.nn.embedding_lookup(self.tempEmbeddings, self.train_labels)
#         labed_bias = tf.nn.embedding_lookup(self.tempBias,self.train_labels)
#         dotProduct = tf.reduce_sum( tf.mul(target_embed ,label_embed) ,1)
#         log_cooccurrences = tf.log(tf.to_float(self.coor))
#         sumUp = tf.add_n([dotProduct,target_bias,labed_bias,tf.neg(log_cooccurrences)])
#         scaling_factor = tf.constant([0.75], dtype=tf.float32,
#                                          name="scaling_factor")
        
#         weighting_factor = tf.minimum(1.0,tf.pow(tf.div(self.coor, 100),scaling_factor ))
        
        self.example_cost = 0#tf.mul(sumUp,weighting_factor)
        
        # Define the cost function (here, the exp and sum are built in)
        self.total_cost = tf.reduce_mean(self.example_cost)
        
        # This library call performs the main SGD update equation
        self.optimizer = tf.train.GradientDescentOptimizer(self.learning_rate).minimize(self.total_cost)
        
        # Create an operation to fill zero values in for W and b
        self.init = tf.initialize_all_variables()
        
        # Initialize the model
        self.sess = tf.Session()
        self.sess.run(self.init)
        
    def train(self, cooccurrences, nonzero_pairs, num_words):
        self.embeddings = None  # If we restart training, make sure to clear the cached embeddings
        print 'Training.'
        
        # Training cycle - In one epoch, we'll visit each nonzero entry in cooccurrences once
        for epoch in range(self.training_epochs):
            random.shuffle(nonzero_pairs)

            avg_cost = 0.
            total_batches = int(len(nonzero_pairs) / self.batch_size)
            
            # Loop over all batches in epoch
            for i in range(total_batches):
                # Assemble a minibatch dictionary to feed to `sess.run()`
                i_input = [item[0] for item in nonzero_pairs[i * self.batch_size : (i + 1) * self.batch_size]]
                j_input = [item[1] for item in nonzero_pairs[i * self.batch_size : (i + 1) * self.batch_size]]
                coor_input = [cooccurrences[item[0]][item[1]] for item in 
                              nonzero_pairs[i * self.batch_size : (i + 1) * self.batch_size]]
                
        
                feed = {self.train_inputs : i_input,
                        self.train_labels : j_input,
                        self.coor : coor_input }
                pass # TODO: Replace

                # Run the optimizer to take a gradient step, and also fetch the value of the 
                # cost function for logging
                _, c = self.sess.run([self.optimizer, self.total_cost], 
                                     feed_dict=feed)
                                                                    
                # Compute average loss
                avg_cost += c / total_batches
                
            # Display some statistics about the step
            if (epoch+1) % self.display_epoch_freq == 0:
                self.cache_embeddings()  # Make sure we run scoring with a fresh copy of the embeddings
                print "Epoch:", (epoch+1), "Cost:", avg_cost, "Score:", score(self)

    def cache_embeddings(self):
        # Fill in self.embeddings with a matrix (in NumPy format) containing one vector per word, 
        # representing the final output of GloVe. It should be possible to index into that
        # matrix using `get_embedding` below.
        #self.embeddings = None  # TODO: Replace
        self.embeddings = self.sess.run(self.tempEmbeddings) 

    def get_embedding(self, index):
        if self.embeddings is None:
            cache_embeddings()
        return self.embeddings[index, :]

# %% [markdown]
# ### Training a working model (30%)

# %% [markdown]
# You should use the following commands to train the model for at least 2000 steps. If your model works, it will usually converge to a score of 10 within that many steps.
#
# Tips:
#
# - You cannot run this until you've completed the previous code block. That's because the starter code doesn't actually define at trainable model.
# - The score and cost for the first few hundred epochs of training will vary quite a bit due to the random initialization. The real measure of success is how the model does once it nears convergence.
# - Make sure to show the full output for a real run in your notebook when you submit. I will not retrain your model to grade it.

# %%
model = glove(len(vocabulary))  # Create the model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-945dd39287e7> in <module>()
# ----> 1 model = glove(len(vocabulary))  # Create the model
#
# NameError: name 'glove' is not defined

# %%
model.train(cooccurrences, nonzero_pairs, len(vocabulary))  # Train it
# Out:
# Training.
# Epoch: 25 Cost: -0.834859642116 Score: 6
# Epoch: 50 Cost: -1.33570422909 Score: 6
# Epoch: 75 Cost: -1.85045028094 Score: 6
# Epoch: 100 Cost: -2.38557416742 Score: 7
# Epoch: 125 Cost: -2.97219228022 Score: 7
# Epoch: 150 Cost: -3.71921136162 Score: 7
# Epoch: 175 Cost: -4.91745590441 Score: 7
# Epoch: 200 Cost: -7.3189608834 Score: 7
# Epoch: 225 Cost: -13.1231676448 Score: 7
# Epoch: 250 Cost: -28.2738183628 Score: 7
# Epoch: 275 Cost: -70.0339506901 Score: 7
# Epoch: 300 Cost: -183.420447147 Score: 7
# Epoch: 325 Cost: -501.722081271 Score: 8
# Epoch: 350 Cost: -1377.59571977 Score: 8
# Epoch: 375 Cost: -3805.3445638 Score: 8
# Epoch: 400 Cost: -10542.8104729 Score: 8
# Epoch: 425 Cost: -29262.723692 Score: 8
# Epoch: 450 Cost: -80797.8362926 Score: 8
# Epoch: 475 Cost: -227386.439157 Score: 8
# Epoch: 500 Cost: -625392.892992 Score: 8
# Epoch: 525 Cost: -1760017.36174 Score: 8
# Epoch: 550 Cost: -4811019.0464 Score: 7
# Epoch: 575 Cost: -13433561.5492 Score: 7
# Epoch: 600 Cost: -37135168.0303 Score: 5
# Epoch: 625 Cost: -102826249.091 Score: 8
# Epoch: 650 Cost: -285958798.061 Score: 7
# Epoch: 675 Cost: -795651203.394 Score: 7
# Epoch: 700 Cost: -2218645434.18 Score: 6
# Epoch: 725 Cost: -6111408760.24 Score: 3
# Epoch: 750 Cost: -17124408172.6 Score: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-1eb662e674ae> in <module>()
# ----> 1 model.train(cooccurrences, nonzero_pairs, len(vocabulary))  # Train it
#
# <ipython-input-28-32ecffa6515a> in train(self, cooccurrences, nonzero_pairs, num_words)
#      87                 # cost function for logging
#      88                 _, c = self.sess.run([self.optimizer, self.total_cost],
# ---> 89                                      feed_dict=feed)
#      90
#      91                 # Compute average loss
#
# /share/apps/tensorflow/20160721/python2.7/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     380     try:
#     381       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 382                          run_metadata_ptr)
#     383       if run_metadata:
#     384         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /share/apps/tensorflow/20160721/python2.7/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     653     movers = self._update_with_movers(feed_dict_string, feed_map)
#     654     results = self._do_run(handle, target_list, unique_fetches,
# --> 655                            feed_dict_string, options, run_metadata)
#     656
#     657     # User may have fetched the same tensor multiple times, but we
#
# /share/apps/tensorflow/20160721/python2.7/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     721     if handle is None:
#     722       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 723                            target_list, options, run_metadata)
#     724     else:
#     725       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /share/apps/tensorflow/20160721/python2.7/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     728   def _do_call(self, fn, *args):
#     729     try:
# --> 730       return fn(*args)
#     731     except errors.OpError as e:
#     732       message = compat.as_text(e.message)
#
# /share/apps/tensorflow/20160721/python2.7/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     710         return tf_session.TF_Run(session, options,
#     711                                  feed_dict, fetch_list, target_list,
# --> 712                                  status, run_metadata)
#     713
#     714     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Part 2: Questions (40%)

# %% [markdown]
# Fill in your answers below.

# %% [markdown]
# **Q1:** What do the entries on the diagonal of the `cooccurrences` matrix represent?

# %% [markdown]
# **Q2:** Deleting the weighting function $F$ should hurt the performance of the model. Why would you expect this to be the case?

# %% [markdown]
# **Q3:** What would you expect to happen if you used a learning rate of 0.0001. Why? (You're welcome to try it, but that shouldn't be the sole basis for your answer.)

# %% [markdown]
# **Q4:** If you used 100 times more training data, would the model take 100 times as long to train? Just as long as now? Somewhere in between? Choose one and (informally) defend your answer.
